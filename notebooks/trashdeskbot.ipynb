# %% [markdown]
# Steps:
# 1. Download LeRobot and Connect to hugging face
# 2. Set vars and Upload dataset
# 3. Choose GPU, check it, check huggingface log in
# 4. Train ACT
# 5. Save checkpoints to computer
# 6. Upload to huggingface

# %%
# %cd /content
# !rm -rf lerobot
# !git clone --depth 1 https://github.com/huggingface/lerobot.git
# %cd /content/lerobot
# !pip install -e .
# Out:
# /content
# Cloning into 'lerobot'...
# remote: Enumerating objects: 1169, done.
# remote: Counting objects: 100% (1169/1169), done.
# remote: Compressing objects: 100% (1029/1029), done.
# remote: Total 1169 (delta 174), reused 607 (delta 100), pack-reused 0 (from 0)
# Receiving objects: 100% (1169/1169), 6.31 MiB | 21.25 MiB/s, done.
# Resolving deltas: 100% (174/174), done.
# Filtering content: 100% (50/50), 69.11 MiB | 4.82 MiB/s, done.
# /content/lerobot
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Building editable for lerobot (pyproject.toml) ... done
# ...

# %%
from huggingface_hub import login

login()

# %%
# !hf auth whoami
# Out:
# Hint: A new version of huggingface_hub (1.22.0) is available! You are using version 1.20.1.
# To update, run: hf update
# ✓ Logged in
#   user: Gracexu28
#   orgs: columbia

# %%
# !nvidia-smi
# Out:
# Tue Jul  7 06:28:20 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0             47W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
HF_USER = "Gracexu28"

DATASET = f"{HF_USER}/so101_desk_trash_merged"

POLICY_REPO_ID = f"{HF_USER}/act_desk_trash"
OUTPUT_DIR = "outputs/train/act_so101_desk_trash"

# %%
pip install 'lerobot[dataset]'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 38.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 67.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
cmd = f"""
lerobot-train \
  --dataset.repo_id={DATASET} \
  --policy.type=act \
  --output_dir={OUTPUT_DIR} \
  --job_name=act_desk_trash \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id={POLICY_REPO_ID}
"""

# !{cmd}
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# INFO 2026-07-07 06:33:56 ot_train.py:232 {'batch_size': 8,
#  'checkpoint_path': None,
#  'cudnn_deterministic': False,
#  'dataset': {'depth_output_unit': 'mm',
#              'episodes': None,
#              'eval_split': 0.0,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
# ...
